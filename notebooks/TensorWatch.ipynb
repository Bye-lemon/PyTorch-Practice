# %%
import tensorwatch as tw
from models.CNN import AlexNet, VGG16, GoogLeNet

# %matplotlib inline

# %%
model = GoogLeNet()

# %%
tw.draw_model(model, input_shape=[4, 3, 224, 224], orientation="TB")
# Out:
# torch.Size([4, 480, 14, 14])
# torch.Size([4, 528, 14, 14])

# %%
tw.model_stats(model, input_shape=[4, 3, 224, 224])
# Out:
# C:\Users\Bye_l\PycharmProjects\Practice\models\CNN.py:170: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(x)
# C:\Users\Bye_l\PycharmProjects\Practice\models\CNN.py:229: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = F.softmax(x)
# C:\Users\Bye_l\Anaconda3\lib\site-packages\tensorwatch\model_graph\torchstat_utils.py:35: RuntimeWarning: overflow encountered in long_scalars
#   self.Flops = sum((l.Flops for l in self.layer_stats))
#                          module name        input shape       output_shape  parameters   infer memory(MB)           MAdd           Flops   MemRead(B)  MemWrite(B)  duration
# 0                       step1.0.conv   (4, 3, 224, 224)  (4, 64, 112, 112)       9,472              12.25    236,027,904     475,267,072    2,560,000   12,845,056  0.044879
# ...

# %%
import torch
import torchviz

x = torch.rand(4, 3, 227, 227)
y = model(x)
g = torchviz.make_dot(y)
g.view()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\graphviz\backend.py in run(cmd, input, capture_output, check, quiet, **kwargs)
#     158     try:
# --> 159         proc = subprocess.Popen(cmd, startupinfo=get_startupinfo(), **kwargs)
#     160     except OSError as e:
#
# ~\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     774                                 errread, errwrite,
# --> 775                                 restore_signals, start_new_session)
#     776         except:
#
# ...
