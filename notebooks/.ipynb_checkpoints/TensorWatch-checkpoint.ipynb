# %%
import torch
import tensorwatch as tw
from models.CNN import AlexNet
import torchvision.models

# %matplotlib inline

# %%
model = AlexNet()
tw.draw_model(model, input_shape=[4, 3, 227, 227], orientation="TB")

# %%
tw.model_stats(model, input_shape=[1, 3, 227, 227])
# Out:
#    module name       input shape      output_shape  parameters   infer memory(MB)           MAdd          Flops   MemRead(B) MemWrite(B)  duration
# 0        conv1  (1, 3, 227, 227)   (1, 96, 55, 55)      34,944    1.1077880859375    210,830,400    105,705,600      758,124   1,161,600  0.010971
# 1          bn1   (1, 96, 55, 55)   (1, 96, 55, 55)         192    1.1077880859375      1,161,600        580,800    1,162,368   1,161,600  0.000999
# 2     dropout1   (1, 96, 27, 27)   (1, 96, 27, 27)           0    0.2669677734375              0              0            0           0  0.000000
# 3        conv2   (1, 96, 27, 27)  (1, 256, 27, 27)     614,656       0.7119140625    895,795,200    448,084,224    2,738,560     746,496  0.027927
# 4          bn2  (1, 256, 27, 27)  (1, 256, 27, 27)         512       0.7119140625        746,496        373,248      748,544     746,496  0.000998
# ...

# %%
model_offical = torchvision.models.alexnet(pretrained=True)
tw.draw_model(model_offical, input_shape=[4, 3, 227, 227])
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to C:\Users\Bye_l/.cache\torch\checkpoints\alexnet-owt-4df8aa71.pth
# ...
